# %%
import pandas as pd
import numpy as np

# %%
network_data_path = "./dataset.csv"
network_data = pd.read_csv(network_data_path, names=["indegree","outdegree","avg_ratings_gave","avg_ratings_received","std_ratings_gave","std_ratings_received","from_rating_top_1_diff","from_rating_top_2_diff","from_rating_last_1_diff","from_rating_last_2_diff","from_rating_top_1_diff_norm","from_rating_top_2_diff_norm","to_rating_top_1_diff","to_rating_top_2_diff","to_rating_last_1_diff","to_rating_last_2_diff","to_rating_top_1_diff_norm","to_rating_top_2_diff_norm","label"])
network_data
# Out:
#       indegree  outdegree  avg_ratings_gave  avg_ratings_received  \
# 0    -0.085573  -0.276466          0.420398             -0.228172
# 1    -0.085573  -0.342881         -0.087638             -0.228172
# 2    -0.085573  -0.341741          0.580352             -0.228172
# 3    -0.085573  -0.310101          0.482170             -0.228172
# 4    -0.085573  -0.345732         -0.310301             -0.228172
# ...        ...        ...               ...                   ...
# 9961 -0.085573  -0.269340          0.573755             -0.228172
# 9962 -0.041916  -0.346302         -3.872916              2.162915
# 9963 -0.085573  -0.296419          0.096855             -0.228172
# 9964 -0.085573  -0.282167          0.323052             -0.228172
# 9965 -0.085573   0.181599          0.458681             -0.228172
#
#       std_ratings_gave  std_ratings_received  from_rating_top_1_diff  \
# 0            -0.457359             -0.208754               -0.715123
# ...

# %%
network_data=(network_data-network_data.mean())/network_data.std()

# %%
network_data.describe()
# Out:
#            indegree     outdegree  avg_ratings_gave  avg_ratings_received  \
# count  9.966000e+03  9.966000e+03      9.966000e+03          9.966000e+03
# mean   1.568527e-17  2.388439e-17     -6.195682e-16         -5.632438e-17
# std    1.000000e+00  1.000000e+00      1.000000e+00          1.000000e+00
# min   -8.557286e-02 -3.463020e-01     -3.872916e+00         -2.281722e-01
# 25%   -8.557286e-02 -3.366105e-01      4.596023e-02         -2.281722e-01
# 50%   -8.557286e-02 -2.855876e-01      2.954295e-01         -2.281722e-01
# 75%   -8.557286e-02 -8.434659e-02      4.572043e-01         -2.281722e-01
# max    4.417505e+01  4.587786e+01      1.471006e+00          5.802447e+00
#
#        std_ratings_gave  std_ratings_received  from_rating_top_1_diff  \
# count      9.966000e+03          9.966000e+03            9.966000e+03
# mean       7.450503e-17          9.197272e-17           -1.689731e-16
# std        1.000000e+00          1.000000e+00            1.000000e+00
# ...

# %%
network_data.to_csv("new_dataset.csv", index=False, header=False)

# %%
network_data["label"] = network_data["label"] > 0

# %%
network_data["label"] = network_data["label"].astype(int)

# %%
network_data["label"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 9961    1
# 9962    0
# 9963    1
# 9964    1
# 9965    1
# Name: label, Length: 9966, dtype: int64

# %%
network_data.describe()
# Out:
#            indegree     outdegree  avg_ratings_gave  avg_ratings_received  \
# count  9.966000e+03  9.966000e+03      9.966000e+03          9.966000e+03
# mean   1.568527e-17  2.388439e-17     -6.195682e-16         -5.632438e-17
# std    1.000000e+00  1.000000e+00      1.000000e+00          1.000000e+00
# min   -8.557286e-02 -3.463020e-01     -3.872916e+00         -2.281722e-01
# 25%   -8.557286e-02 -3.366105e-01      4.596023e-02         -2.281722e-01
# 50%   -8.557286e-02 -2.855876e-01      2.954295e-01         -2.281722e-01
# 75%   -8.557286e-02 -8.434659e-02      4.572043e-01         -2.281722e-01
# max    4.417505e+01  4.587786e+01      1.471006e+00          5.802447e+00
#
#        std_ratings_gave  std_ratings_received  from_rating_top_1_diff  \
# count      9.966000e+03          9.966000e+03            9.966000e+03
# mean       7.450503e-17          9.197272e-17           -1.689731e-16
# std        1.000000e+00          1.000000e+00            1.000000e+00
# ...

# %%
network_data.to_csv("dataset1.csv", index=False, header=False)

# %%
network_data
# Out:
#       indegree  outdegree  avg_ratings_gave  avg_ratings_received  \
# 0    -0.085573  -0.276466          0.420398             -0.228172
# 1    -0.085573  -0.342881         -0.087638             -0.228172
# 2    -0.085573  -0.341741          0.580352             -0.228172
# 3    -0.085573  -0.310101          0.482170             -0.228172
# 4    -0.085573  -0.345732         -0.310301             -0.228172
# ...        ...        ...               ...                   ...
# 9961 -0.085573  -0.269340          0.573755             -0.228172
# 9962 -0.041916  -0.346302         -3.872916              2.162915
# 9963 -0.085573  -0.296419          0.096855             -0.228172
# 9964 -0.085573  -0.282167          0.323052             -0.228172
# 9965 -0.085573   0.181599          0.458681             -0.228172
#
#       std_ratings_gave  std_ratings_received  from_rating_top_1_diff  \
# 0            -0.457359             -0.208754               -0.715123
# ...
